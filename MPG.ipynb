# %%
import pandas as pd

# %%
df = pd.read_csv("mpg.csv")

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df["horsepower"].mode()
# Out:
# 0    150
# Name: horsepower, dtype: object

# %%
df["horsepower"] = df["horsepower"].replace("?","105")

# %%
df["horsepower"] = df['horsepower'].astype('int')

# %%
df["horsepower"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 398 entries, 0 to 397
# Series name: horsepower
# Non-Null Count  Dtype
# --------------  -----
# 398 non-null    int64
# dtypes: int64(1)
# memory usage: 3.2 KB

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(["name","mpg"],axis=1)

# %%
y =df["mpg"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 32)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print(y_pred)
# Out:
# [29.0081307  32.93344661 32.13980196 20.77325254 23.1871596  22.39224062
#  26.62157542 29.90430682 34.39279946 26.53876427 28.98387142 20.97392713
#  13.0018975  16.26270143 25.65532674 25.96605594 30.25186657 24.84928874
#  31.00855826 26.12753187 24.37197747 21.00505996 30.68342765 31.57287553
#  29.96694831 24.73893264  9.61359302 34.08273602 18.45656945 27.32564786
#  25.63399846 20.14105742 29.05828048 23.15634416 10.56537737 28.77372042
#  10.69825235 33.57305949 16.99534099 17.28418571 26.09307285  5.77564778
#  22.81964014 23.92367766 16.02249605 26.93448174 35.47429332 21.80264187
#  26.84941022 11.85847596 19.83029465 16.8861365  30.93838344 19.90923884
#  32.00393943 15.34004474 27.01000334 27.53784512 14.08576639 25.32221558
#  19.96779302 33.55051165 12.24393282 22.43272506 26.04978368 20.55729465
#  25.85967778 27.4463885  32.39196673 31.0084149  26.0478555  16.07013074
#  16.83303041 33.6281839  20.69016241 22.0643446  36.58307847 33.10369743
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7814448594776768

# %% [markdown]
# # limitation in linear regression
# * It is assuemed to linear relationship between features and target

# %% [markdown]
# # joblib
# * It is a python library which is used to save and use machine learning models

# %%
import joblib

# %%
joblib.dump(model,"mpg.h5")
# Out:
# ['mpg.h5']

# %%
model = joblib.load("mpg.h5")

# %%
model.predict([[8, 307.0,135,3504,13.0,70,1]])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.3466746])
